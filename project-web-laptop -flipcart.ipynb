# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'}

# %%
url=r'https://www.flipkart.com/search?q=best+laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'

# %%
page=requests.get(url,headers=headers)

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %% [markdown]
# soup

# %%
###first half division

product=soup.findAll('div',class_='_2kHMtA')

# %% [markdown]
# product

# %%
###length and type of container
print(len(product),type(product))
# Out:
# 24 <class 'bs4.element.ResultSet'>

# %%
## for one set of imformamtion
f=open('laptop_info.csv','wb')
f.write('productName,productStar,product_rating,product_review,currentPrice,mrp,processor,ram,storage,image\n'.encode())


for i in product:
    name=i.find_all('div','_4rR01T')
    try:
        productName=name[0].text.strip().split('-')[0]
    except:
        productName=np.nan
        
    star=i.findAll('div','_3LWZlK')
    try:
        productStar=star[0].text
    except:
        productStar=np.nan
        
    rating=i.find('span','_2_R_DZ')
   
    try:
        rat_rev=re.findall('\d+,?\d*',rating.text)
        product_rating=rat_rev[0].replace(',','')
        product_review=rat_rev[1].replace(',','')
    except:
        product_rating=np.nan
        product_review=np.nan
        
    try:
        currentPrice=i.find('div','_30jeq3 _1_WHN1')
        currentPrice=currentPrice.text.replace(',','')
    except:
        currentPrice=np.nan
        
    
    mrp=i.find('div','_3I9_wc _27UcVY')
    try:
        mrp=mrp.text.replace(',','')
    except:
        mrp=np.nan
        
    info=i.find_all('li','rgWa7D')
    try:
        processor=info[0].text
    except:
        processor=np.nan
        
    try:
        ram=info[1].text
    except:
        ram=np.nan
        
    try:
        storage=info[3].text
    except:
        storage=np.nan
        
    image=i.img
    try:
        image=image.get('src')
    except:
        image=np.nan
    f.write(f'{productName},{productStar},{product_rating},{product_review},{currentPrice},{mrp},{processor},{ram},{storage},{image}\n'.encode())
    
f.close()

# %%
for i in product:
    name=i.find_all('div','_4rR01T')
    try:
        productName=name[0].text.strip().split('-')[0]
    except:
        productName=np.nan

# %%
#https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=7ec220e8-4f02-4150-9e0b-9e90cf692f4b&as-searchtext=laptop%27&page=1
url= 'https://www.flipkart.com/search?q=best+laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2'

# %%
###for whole laptop selection  pages

f=open('laptop_data.csv','wb')
f.write('productName,productStar,product_rating,product_review,currentPrice,mrp,processor,ram,storage,image\n'.encode())

for j in range(1,45):
    website='https://www.flipkart.com/search?q=best+laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(j)
    soup=BeautifulSoup(page.content,'html.parser')
    product=soup.findAll('div',class_='_2kHMtA')
    for i in product:
        name=i.find_all('div','_4rR01T')
        try:
            productName=name[0].text.strip().split('-')[0]
        except:
            productName=np.nan
        
        star=i.findAll('div','_3LWZlK')
        try:
            productStar=star[0].text
        except:
            productStar=np.nan
        
        rating=i.find('span','_2_R_DZ')
        try:
            rat_rev=re.findall('\d+,?\d*',rating.text)
            product_rating=rat_rev[0].replace(',','')
            product_review=rat_rev[1].replace(',','')
        except:
            product_rating=np.nan
            product_review=np.nan
        try:
            currentPrice=i.find('div','_30jeq3 _1_WHN1')
            currentPrice=currentPrice.text.replace(',','')
        except:
            currentPrice=np.nan
        
    
        mrp=i.find('div','_3I9_wc _27UcVY')
        try:
            mrp=mrp.text.replace(',','')
        except:
            mrp=np.nan
        
        info=i.find_all('li','rgWa7D')
        try:
           processor=info[0].text
        except:
            processor=np.nan
        
        try:
            ram=info[1].text
        except:
            ram=np.nan
        
        try:
            storage=info[3].text
        except:
            storage=np.nan
        
        image=i.img
        try:
            image=image.get('src')
        except:
            image=np.nan
        f.write(f'{productName},{productStar},{product_rating},{product_review},{currentPrice},{mrp},{processor},{ram},{storage},{image}\n'.encode())
f.close()

# %%
df=pd.read_csv('laptop_data.csv')

# %%
df
# Out:
#                                             productName  productStar  \
# 0                                  HP Core i3 11th Gen           4.2
# 1                            HP Athlon Dual Core 3050U           4.2
# 2                                  HP Core i3 11th Gen           4.2
# 3                            HP Athlon Dual Core 3050U           3.9
# 4                            HP Athlon Dual Core 3050U           NaN
# ...                                                 ...          ...
# 1051  HP Laptop with Backlit Keyboard Core i3 11th Gen           4.1
# 1052                      HP Pavilion Core i5 12th Gen           4.2
# 1053                        HP Victus Core i5 11th Gen           4.3
# 1054               MSI GF65 Thin Hexa Core i5 10th Gen           4.5
# 1055                               HP Core i5 12th Gen           4.2
#
#       product_rating  product_review currentPrice      mrp  \
# 0                NaN             NaN       ₹41990   ₹51748
# ...
